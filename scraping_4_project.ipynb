# %% [markdown]
# ## Assignment 3
#
# ### scraping news article from article_list.csv

# %%
# Import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

print("✅ Libraries imported successfully")
# Out:
# ✅ Libraries imported successfully

# %%
df = pd.read_csv('/workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/serverless/project/article_list.csv', 
                 encoding='utf-8')

df
# Out:
#           Channels                                         News Title  \
# 0   The Daily Star  New Polls Timing BNP upbeat process irks Jamaa...
# 1   The Daily Star  BNP announces candidates for 36 more constitue...
# 2   The Daily Star                 Seat-sharing snub riles BNP allies
# 3   The Daily Star        Seat sharing BNP still keeps allies hanging
# 4   The Daily Star  Election to be tough for BNP, bigger test if v...
# 5   The Daily Star                Old habits die hard? BNP’s response
# 6   The Daily Star     BNP at 47: Caught between prospects and perils
# 7   The Daily Star  BNP’s show of force on Airport Road and a poli...
# 8   The Daily Star  Fulfilling Uprising's Aspirations: Correction ...
# 9      Prothom Alo                BNP rethinks its approach to allies
# 10     Prothom Alo  BNP’s Masuduzzaman quits race over 'security i...
# 11     Prothom Alo  Meeting of 29 party allies, decision to sort t...
# 12     Prothom Alo  66pc say BNP will win the most seats in the el...
# 13     Prothom Alo  BNP wants to push ahead with election plans am...
# 14     Prothom Alo  Candidates busy in campaign, but Reza Kibria d...
# 15     Prothom Alo  Those who seek to exploit crisis are enemies o...
# 16     Prothom Alo  BNP wants to make Tarique Rahman’s return “mem...
# 17     Prothom Alo  BNP in dilemma over implementation of reform r...
# 18     Prothom Alo                      Is BNP stepping into trouble?
# 19       প্রথম আলো  বিএনপি ছেড়ে এনসিপির প্রার্থী হয়ে আলোচনায় সা...
# 20       প্রথম আলো  ‘দরজায় তালা লাগিয়ে’ বিএনপি নেতার ঘরে আগুন, ঘ...
# 21       প্রথম আলো        সরকারের মান-অভিমানের সুযোগ নেই: তারেক রহমান
# 22       প্রথম আলো  তারেক রহমানের প্রত্যাবর্তন, সাতটি ট্রেন ভাড়া ...
# 23       প্রথম আলো  নারায়ণগঞ্জে সরে দাঁড়ানো বিএনপি প্রার্থী মাসু...
# 24       প্রথম আলো  ভোটের প্রচারকৌশল ও ভোট নিয়ে প্রশিক্ষণের বড় ক...
# 25       প্রথম আলো  চট্টগ্রামে এক আসনে মনোনয়নপত্র নিলেন বিএনপির ত...
# 26       প্রথম আলো             কোন আসনে বিএনপির প্রার্থী কে, দেখে নিন
# 27       প্রথম আলো           এক কোটি ‘সৎ মানুষের’ খোঁজ পাবে কি বিএনপি
# 28       প্রথম আলো                           কার ওপর ভরসা করছে বিএনপি
#
#                                              News url Language  Sentiment
# 0   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 1   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 2   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 3   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 4   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 5   https://www.thedailystar.net/opinion/views/new...       en        NaN
# 6   https://www.thedailystar.net/news/bangladesh/p...       en        NaN
# 7   https://www.thedailystar.net/opinion/views/new...       en        NaN
# 8   https://www.thedailystar.net/opinion/editorial...       en        NaN
# 9   https://en.prothomalo.com/bangladesh/politics/...       en        NaN
# 10    https://en.prothomalo.com/bangladesh/9pkzu86yuv       en        NaN
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) "
    + " Chrome/39.0.2171.95 Safari/537.36"
}

for i, url in enumerate(df["News url"][:9]):
    
    star_response = requests.get(url, headers=headers)
    daily_star = BeautifulSoup(star_response.content, "html.parser")
    
    title_star = daily_star.find("h1").get_text(strip= True)
    star_body = daily_star.find("article")
    star_paragraphs = star_body.find_all("p")
    star_text = "\n".join([p.get_text(strip=True) for p in star_paragraphs])
    all_daily_star.append(star_text)

# %%
# check if it worked
print(all_daily_star[0][:500]) # 0 for the first article
print(all_daily_star[3][:500]) # 3 for the third article
# Out:
# Even though a week has passed since the announcement of the election schedule, BNP allies still do not know how many seats they might be allotted.
# They said frustration is deepening within their ranks as the BNP has kept the seat-sharing issue hanging for so long.
# The parties that were part of the simultaneous movement with the BNP also claimed the BNP did not hold any discussions with them before unveiling its nominees in most constituencies.
# In efforts to assuage the allies, the BNP held one-t

# %%
# scrape all prothomalo

all_prothomalo = []

for i, url in enumerate(df["News url"][10:]):
    
    protho_response = requests.get(url, headers=headers)
    prothomalo = BeautifulSoup(protho_response.content, "html.parser")
    
    prothomalo_title = prothomalo.find("h1").get_text(strip= True)
    prothomalo_body = prothomalo.find_all("div", class_="story-element-text")
    prothomalo_text = "\n".join([p.get_text(strip=True) for p in prothomalo_body])

    all_prothomalo.append(prothomalo_text)

# %%
# check if it worked
print(all_prothomalo[0][:500])
print(all_prothomalo[5][:500])
print(all_prothomalo[15][:500])
# Out:
# Citing security concerns amid the recent situation, BNP-nominated candidate Mohammad Masuduzzaman, a businessman and sports organiser, has announced his withdrawal from the Narayanganj-5 (City-Port) constituency election. He made the announcement today, Tuesday afternoon, during a discussion with journalists at the Narayanganj Press Club.Mohammad Masuduzzaman is a former president of the Narayanganj Chamber of Commerce and Industries and the Managing Director of Model Group.In addition to journa
# Bangladesh Nationalist Party (BNP) Secretary General Mirza Fakhrul Islam Alamgir has condemned the attacks on the offices of Prothom Alo and The Daily Star, describing those who exploit the country’s crisis situation to carry out such acts, as enemies of the nation.Following the attacks on the offices of Prothom Alo and The Daily Star, Mirza Fakhrul posted a statement on his verified Facebook page today, Friday, where in addition to protesting he reminded the interim government of its responsibi
# ত্রয়োদশ জাতীয় সংসদ নির্বাচনে চট্টগ্রামের বিভিন্ন আসনে প্রতিদ্বন্দ্বিতা করার জন্য মনোনয়নপত্র সংগ্রহ শুরু করেছেন প্রার্থীরা। আজ বৃহস্পতিবার মনোনয়নপত্র নিয়েছেন বিএনপি, জামায়াতে ইসলামীসহ বিভিন্ন রাজনৈতিক দলের ১৮ প্রার্থী। এর মধ্যে চট্টগ্রাম-১৫ (সাতকানিয়া-লোহাগাড়া) আসনে মনোনয়নপত্র সংগ্রহ করেছেন বিএনপির তিন নেতা।দক্ষিণ জেলা বিএনপির সদস্য নাজমুল মোস্তফা আমিন চট্টগ্রাম-১৫ (সাতকানিয়া-লোহাগাড়া) থেকে মনোনয়নপত্র নিয়েছেন। তাঁকে বিএনপি প্রার্থী করেছে। একই আসন থেকে চট্টগ্রাম দক্ষিণ জেলা বিএনপির যুগ্ম আহ্বায়ক জ
